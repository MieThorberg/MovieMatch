# %% [markdown]
# # Clusters

# %%
import modules.clusters.ClusterCompare as compare
import modules.clusters.ClusterCollection as collection
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %% [markdown]
# ### Cluster matrix

# %%
collection.make_Cluster_metrix(9)
# Out:
# C:\Users\miemt\Desktop\python\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# C:\Users\miemt\Desktop\python\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# C:\Users\miemt\Desktop\python\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# C:\Users\miemt\Desktop\python\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# C:\Users\miemt\Desktop\python\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# ...

# %% [markdown]
# ### Example with vote-average and revenue clustering
# We will look at the two features vote-average and revenue

# %%
compare.get_elbow_diagram("vote_average", "revenue", 5)
# Out:
# C:\Users\miemt\Desktop\MovieMatch\modules\clusters\ClusterCompare.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
compare.create_cluster_scatter()
# Out:
# C:\Users\miemt\Desktop\MovieMatch\modules\clusters\ClusterCompare.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### Example with revenue and budget clustering
# We will look at the two features revenue and budget

# %%
compare.get_elbow_diagram("revenue", "budget", 5)
# Out:
# C:\Users\miemt\Desktop\MovieMatch\modules\clusters\ClusterCompare.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
compare.create_cluster_scatter("revenue", "budget", 5)
# Out:
# C:\Users\miemt\Desktop\MovieMatch\modules\clusters\ClusterCompare.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
